# %%
import sipm_position_histograms as sph
import sipm_1d_histograms as soh

# %%
import os

path_corners = "/home/smallsat/Desktop/grips-impress/geant4-impress-grips-piggyback/build/data-out/rod_position_data"

cornerdir = os.listdir(path_corners)
print(cornerdir)
# Out:
# ['4x5x40_GAGG_RRR_TEF_Corner_Test-run2-2023-03-21-12:42:58', '4x5x40_LYSO_RRR_ESR_Corner_Test-run2-2023-03-21-13:17:05', '4x5x40_GAGG_RRR_TEF_Corner_Test-run4-2023-03-21-12:44:41', '4x5x40_LYSO_RRR_ESR_Corner_Test-run4-2023-03-21-13:18:43', '4x5x40_GAGG_RRR_ESR_Corner_Test-run3-2023-03-21-12:55:54', '4x5x40_GAGG_PPP_TEF_Corner_Test-run4-2023-03-21-12:51:28', '4x5x40_GAGG_PPP_TEF_Corner_Test-run1-2023-03-21-12:45:44', '4x5x40_LYSO_PPP_ESR_Corner_Test-run3-2023-03-21-13:22:53', '4x5x40_GAGG_PPP_ESR_Corner_Test-run2-2023-03-21-13:00:28', '4x5x40_LYSO_RRR_ESR_Corner_Test-run1-2023-03-21-13:16:25', '4x5x40_LYSO_PPP_ESR_Corner_Test-run1-2023-03-21-13:19:50', '4x5x40_GAGG_PPP_ESR_Corner_Test-run1-2023-03-21-12:58:10', '4x5x40_GAGG_RRR_TEF_Corner_Test-run3-2023-03-21-12:43:47', '4x5x40_GAGG_PPP_ESR_Corner_Test-run3-2023-03-21-13:02:25', '4x5x40_GAGG_PPP_TEF_Corner_Test-run3-2023-03-21-12:49:28', '4x5x40_LYSO_RRR_TEF_Corner_Test-run3-2023-03-21-13:08:07', '4x5x40_LYSO_PPP_ESR_Corner_Test-run2-2023-03-21-13:21:20', '4x5x40_LYSO_RRR_TEF_Corner_Test-run4-2023-03-21-13:09:03', '4x5x40_GAGG_RRR_ESR_Corner_Test-run4-2023-03-21-12:56:58', '4x5x40_LYSO_PPP_ESR_Corner_Test-run4-2023-03-21-13:24:33', '4x5x40_LYSO_RRR_ESR_Corner_Test-run3-2023-03-21-13:18:02', '4x5x40_GAGG_PPP_ESR_Corner_Test-run4-2023-03-21-13:04:21', '4x5x40_LYSO_PPP_TEF_Corner_Test-run3-2023-03-21-13:12:55', '4x5x40_LYSO_PPP_TEF_Corner_Test-run1-2023-03-21-13:10:05', '4x5x40_GAGG_RRR_TEF_Corner_Test-run1-2023-03-21-12:42:22', '4x5x40_LYSO_RRR_TEF_Corner_Test-run2-2023-03-21-13:07:27', '4x5x40_GAGG_PPP_TEF_Corner_Test-run2-2023-03-21-12:47:32', '4x5x40_LYSO_PPP_TEF_Corner_Test-run4-2023-03-21-13:14:42', '4x5x40_GAGG_RRR_ESR_Corner_Test-run1-2023-03-21-12:53:53', '4x5x40_LYSO_PPP_TEF_Corner_Test-run2-2023-03-21-13:11:26', '4x5x40_GAGG_RRR_ESR_Corner_Test-run2-2023-03-21-12:54:47', '4x5x40_LYSO_RRR_TEF_Corner_Test-run1-2023-03-21-13:06:41']

# %%
scintillators = ["LYSO", "GAGG"]
surface_finishes = ["RRR", "PPP"]
reflectors = ["ESR", "TEF"]
runs = ["run1", "run2", "run3", "run4"]

dirorder = list()

for scint in scintillators:
    for surf in surface_finishes:
        for ref in reflectors:
            for run in runs:
                name = "4x5x40_"+scint+"_"+surf+"_"+ref+"_Corner_Test-"+run
                for fold in cornerdir:
                    foldname = fold.split("-")[0]+"-"+fold.split("-")[1]
                    if foldname == name:
                        dirorder.append(fold)

print(dirorder)
# Out:
# ['4x5x40_LYSO_RRR_ESR_Corner_Test-run1-2023-03-21-13:16:25', '4x5x40_LYSO_RRR_ESR_Corner_Test-run2-2023-03-21-13:17:05', '4x5x40_LYSO_RRR_ESR_Corner_Test-run3-2023-03-21-13:18:02', '4x5x40_LYSO_RRR_ESR_Corner_Test-run4-2023-03-21-13:18:43', '4x5x40_LYSO_RRR_TEF_Corner_Test-run1-2023-03-21-13:06:41', '4x5x40_LYSO_RRR_TEF_Corner_Test-run2-2023-03-21-13:07:27', '4x5x40_LYSO_RRR_TEF_Corner_Test-run3-2023-03-21-13:08:07', '4x5x40_LYSO_RRR_TEF_Corner_Test-run4-2023-03-21-13:09:03', '4x5x40_LYSO_PPP_ESR_Corner_Test-run1-2023-03-21-13:19:50', '4x5x40_LYSO_PPP_ESR_Corner_Test-run2-2023-03-21-13:21:20', '4x5x40_LYSO_PPP_ESR_Corner_Test-run3-2023-03-21-13:22:53', '4x5x40_LYSO_PPP_ESR_Corner_Test-run4-2023-03-21-13:24:33', '4x5x40_LYSO_PPP_TEF_Corner_Test-run1-2023-03-21-13:10:05', '4x5x40_LYSO_PPP_TEF_Corner_Test-run2-2023-03-21-13:11:26', '4x5x40_LYSO_PPP_TEF_Corner_Test-run3-2023-03-21-13:12:55', '4x5x40_LYSO_PPP_TEF_Corner_Test-run4-2023-03-21-13:14:42', '4x5x40_GAGG_RRR_ESR_Corner_Test-run1-2023-03-21-12:53:53', '4x5x40_GAGG_RRR_ESR_Corner_Test-run2-2023-03-21-12:54:47', '4x5x40_GAGG_RRR_ESR_Corner_Test-run3-2023-03-21-12:55:54', '4x5x40_GAGG_RRR_ESR_Corner_Test-run4-2023-03-21-12:56:58', '4x5x40_GAGG_RRR_TEF_Corner_Test-run1-2023-03-21-12:42:22', '4x5x40_GAGG_RRR_TEF_Corner_Test-run2-2023-03-21-12:42:58', '4x5x40_GAGG_RRR_TEF_Corner_Test-run3-2023-03-21-12:43:47', '4x5x40_GAGG_RRR_TEF_Corner_Test-run4-2023-03-21-12:44:41', '4x5x40_GAGG_PPP_ESR_Corner_Test-run1-2023-03-21-12:58:10', '4x5x40_GAGG_PPP_ESR_Corner_Test-run2-2023-03-21-13:00:28', '4x5x40_GAGG_PPP_ESR_Corner_Test-run3-2023-03-21-13:02:25', '4x5x40_GAGG_PPP_ESR_Corner_Test-run4-2023-03-21-13:04:21', '4x5x40_GAGG_PPP_TEF_Corner_Test-run1-2023-03-21-12:45:44', '4x5x40_GAGG_PPP_TEF_Corner_Test-run2-2023-03-21-12:47:32', '4x5x40_GAGG_PPP_TEF_Corner_Test-run3-2023-03-21-12:49:28', '4x5x40_GAGG_PPP_TEF_Corner_Test-run4-2023-03-21-12:51:28']

# %%
total_sipm_counts = dict()
sipm_sum = 0
for run in cornerdir:
    hits = sph.load_sipm_hits(path_corners + "/" + run + "/sipm-out.tab")
    run_name = run.split('-')[0] + "_" + run.split('-')[1]
    for item in hits:
        sipm_sum += item[0]
    total_sipm_counts[run_name] = sipm_sum
    sipm_sum = 0

print(total_sipm_counts)
# Out:
# {'4x5x40_GAGG_RRR_TEF_Corner_Test_run2': 660439, '4x5x40_LYSO_RRR_ESR_Corner_Test_run2': 553342, '4x5x40_GAGG_RRR_TEF_Corner_Test_run4': 670110, '4x5x40_LYSO_RRR_ESR_Corner_Test_run4': 557865, '4x5x40_GAGG_RRR_ESR_Corner_Test_run3': 672675, '4x5x40_GAGG_PPP_TEF_Corner_Test_run4': 623517, '4x5x40_GAGG_PPP_TEF_Corner_Test_run1': 627162, '4x5x40_LYSO_PPP_ESR_Corner_Test_run3': 529132, '4x5x40_GAGG_PPP_ESR_Corner_Test_run2': 634127, '4x5x40_LYSO_RRR_ESR_Corner_Test_run1': 550241, '4x5x40_LYSO_PPP_ESR_Corner_Test_run1': 529039, '4x5x40_GAGG_PPP_ESR_Corner_Test_run1': 641474, '4x5x40_GAGG_RRR_TEF_Corner_Test_run3': 668238, '4x5x40_GAGG_PPP_ESR_Corner_Test_run3': 638025, '4x5x40_GAGG_PPP_TEF_Corner_Test_run3': 624833, '4x5x40_LYSO_RRR_TEF_Corner_Test_run3': 553680, '4x5x40_LYSO_PPP_ESR_Corner_Test_run2': 527418, '4x5x40_LYSO_RRR_TEF_Corner_Test_run4': 553927, '4x5x40_GAGG_RRR_ESR_Corner_Test_run4': 671696, '4x5x40_LYSO_PPP_ESR_Corner_Test_run4': 529208, '4x5x40_LYSO_RRR_ESR_Corner_Test_run3': 556003, '4x5x40_GAGG_PPP_ESR_Corner_Test_run4': 640238, '4x5x40_LYSO_PPP_TEF_Corner_Test_run3': 514649, '4x5x40_LYSO_PPP_TEF_Corner_Test_run1': 514149, '4x5x40_GAGG_RRR_TEF_Corner_Test_run1': 663890, '4x5x40_LYSO_RRR_TEF_Corner_Test_run2': 549388, '4x5x40_GAGG_PPP_TEF_Corner_Test_run2': 617411, '4x5x40_LYSO_PPP_TEF_Corner_Test_run4': 515781, '4x5x40_GAGG_RRR_ESR_Corner_Test_run1': 667976, '4x5x40_LYSO_PPP_TEF_Corner_Test_run2': 512634, '4x5x40_GAGG_RRR_ESR_Corner_Test_run2': 667541, '4x5x40_LYSO_RRR_TEF_Corner_Test_run1': 548142}

# %%
dimension = "4x5x40"
scintillators = ["LYSO", "GAGG"]
surface_finishes = ["RRR", "PPP"]
reflectors = ["ESR", "TEF"]
runs = ["run1", "run2", "run3", "run4"]

dat2 = list()
for scint in scintillators:
    for surf in surface_finishes:
        for ref in reflectors:
            for run in runs:
                item_name = dimension + "_" + scint + "_" + surf + "_" + ref + "_Corner_Test_" + run
                dat2.append(total_sipm_counts[item_name])

# %%
import matplotlib.pyplot as plt
#%matplotlib qt6

runs_dat = [1,2,3,4]

plt.scatter(runs_dat, dat2[:4],marker='^')
plt.scatter(runs_dat, dat2[4:8],marker='^')
plt.scatter(runs_dat, dat2[8:12],marker='^')
plt.scatter(runs_dat, dat2[12:16],marker='^')
plt.scatter(runs_dat, dat2[16:20],marker='x')
plt.scatter(runs_dat, dat2[20:24],marker='x')
plt.scatter(runs_dat, dat2[24:28],marker='x')
plt.scatter(runs_dat, dat2[28:32],marker='x')
plt.title('Total SiPM Counts Over Runs')
plt.legend(['LSYO_RRR_ESR', 'LYSO_RRR_TEF', 'LYSO_PPP_ESR', 'LYSO_PPP_TEF', 'GAGG_RRR_ESR', 'GAGG_RRR_TEF', 'GAGG_PPP_ESR', 'GAGG_PPP_TEF'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('run number')
plt.ylabel('total counts')
plt.show()

# %%
def corner_hists():
    for fold in dirorder:
        cut_name = fold.split('-')[0]
        add = fold.split('-')[1]
        soh.main(path_corners + '/' + fold, cut_name + " Corner " + add, cut_name + ' SiPM Hit Positions for Corner ' + add)
    return 0

# %%
corner_hists()
# Out:
# 0
